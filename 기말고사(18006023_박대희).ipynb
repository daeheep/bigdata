# %% [markdown]
# <a href="https://colab.research.google.com/github/daeheep/bigdata/blob/main/%EA%B8%B0%EB%A7%90%EA%B3%A0%EC%82%AC(18006023_%EB%B0%95%EB%8C%80%ED%9D%AC).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#글자깨짐 문제 수정을 위해 다음의 코드 실행 
#단계 1: 폰트 설치
import matplotlib.font_manager as fm
# !apt-get -qq -y install fonts-nanum > /dev/null
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
fm._rebuild()

# %%
# 단계 2: 런타임 재시작
import os
os.kill(os.getpid(), 9)

# %%
# 단계 3: 한글 폰트 설정
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm

# 마이너스 표시 문제
mpl.rcParams['axes.unicode_minus'] = False
	
# 한글 폰트 설정
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
font_name = fm.FontProperties(fname=path, size=18).get_name()
plt.rc('font', family=font_name)
fm._rebuild()

# %%
#데이터 불러오기
import pandas as pd
df=pd.read_html('https://ko.wikipedia.org/wiki/%EC%98%AC%EB%A6%BC%ED%94%BD_%EB%A9%94%EB%8B%AC_%EC%A7%91%EA%B3%84', header=0, index_col=0) #맨 위의 헤더를 열 이름, 나라 이름을 인덱스 이름으로
df[0]
# Out:
#                      하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계  \
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)               14           0           0           2      2
# 알제리 (ALG)                  13           5           4           8     17
# 아르헨티나 (ARG)                24          21          25          28     74
# 아르메니아 (ARM)                 6           2           6           6     14
# 오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
# ...                       ...         ...         ...         ...    ...
# 독립 (IOA) [IOA]              3           1           0           1      2
# 독립 참가 (IOP) [IOP]           1           0           1           2      3
# 러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
# 혼성 (ZZX) [ZZX]              3           8           5           4     17
# 총합                         28        5116        5082        5490  15688
#
#                      동계 참가 횟수  Unnamed: 7  Unnamed: 8  Unnamed: 9   계.1  \
# ...

# %% [markdown]
# 1. 하계올림픽 관련 정보만 추출해서 summer라는 데이터프레임에 저장하자. summer 데이터프레임을 나타내보자.

# %%
summer=df[0].iloc[:,:5]  
summer
# Out:
#                      하계 참가 횟수  Unnamed: 2  Unnamed: 3  Unnamed: 4      계
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)               14           0           0           2      2
# 알제리 (ALG)                  13           5           4           8     17
# 아르헨티나 (ARG)                24          21          25          28     74
# 아르메니아 (ARM)                 6           2           6           6     14
# 오스트랄라시아 (ANZ) [ANZ]         2           3           4           5     12
# ...                       ...         ...         ...         ...    ...
# 독립 (IOA) [IOA]              3           1           0           1      2
# 독립 참가 (IOP) [IOP]           1           0           1           2      3
# 러시아 출신 올림픽 선수 (OAR)         0           0           0           0      0
# 혼성 (ZZX) [ZZX]              3           8           5           4     17
# 총합                         28        5116        5082        5490  15688
#
# [153 rows x 5 columns]

# %% [markdown]
#  2. 동계올림픽 관련 정보만 추출해서 winter라는 데이터프레임에 저장하자. winter 데이터프레임을 나타내보자.

# %%
winter=df[0].iloc[:,5:10]  
winter
# Out:
#                      동계 참가 횟수  Unnamed: 7  Unnamed: 8  Unnamed: 9   계.1
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)                0           0           0           0     0
# 알제리 (ALG)                   3           0           0           0     0
# 아르헨티나 (ARG)                19           0           0           0     0
# 아르메니아 (ARM)                 7           0           0           0     0
# 오스트랄라시아 (ANZ) [ANZ]         0           0           0           0     0
# ...                       ...         ...         ...         ...   ...
# 독립 (IOA) [IOA]              0           0           0           0     0
# 독립 참가 (IOP) [IOP]           0           0           0           0     0
# 러시아 출신 올림픽 선수 (OAR)         1           2           6           9    17
# 혼성 (ZZX) [ZZX]              0           0           0           0     0
# 총합                         23        1062        1058        1050  3170
#
# [153 rows x 5 columns]

# %% [markdown]
#  3.summer 데이터 프레임 열 이름을 '하계참가횟수', '금', '은', '동', '하계 계'로 지어서 지정하자. 열 이름을 바꾼 후 summer 데이터프레임을 나타내보자

# %%
summer.columns=['하계참가횟수', '금', '은', '동', '하계 계']
summer
# Out:
#                      하계참가횟수     금     은     동   하계 계
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)             14     0     0     2      2
# 알제리 (ALG)                13     5     4     8     17
# 아르헨티나 (ARG)              24    21    25    28     74
# 아르메니아 (ARM)               6     2     6     6     14
# 오스트랄라시아 (ANZ) [ANZ]       2     3     4     5     12
# ...                     ...   ...   ...   ...    ...
# 독립 (IOA) [IOA]            3     1     0     1      2
# 독립 참가 (IOP) [IOP]         1     0     1     2      3
# 러시아 출신 올림픽 선수 (OAR)       0     0     0     0      0
# 혼성 (ZZX) [ZZX]            3     8     5     4     17
# 총합                       28  5116  5082  5490  15688
#
# [153 rows x 5 columns]

# %% [markdown]
#  4.winter 데이터 프레임 열 이름을 '동계참가횟수', '금', '은', '동', '동계 계'로 지어서 지정하자. 열 이름을 바꾼 후 winter 데이터프레임을 나타내보자.

# %%
winter.columns=['동계참가횟수', '금', '은', '동', '동계 계']
winter
# Out:
#                      동계참가횟수     금     은     동  동계 계
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)              0     0     0     0     0
# 알제리 (ALG)                 3     0     0     0     0
# 아르헨티나 (ARG)              19     0     0     0     0
# 아르메니아 (ARM)               7     0     0     0     0
# 오스트랄라시아 (ANZ) [ANZ]       0     0     0     0     0
# ...                     ...   ...   ...   ...   ...
# 독립 (IOA) [IOA]            0     0     0     0     0
# 독립 참가 (IOP) [IOP]         0     0     0     0     0
# 러시아 출신 올림픽 선수 (OAR)       1     2     6     9    17
# 혼성 (ZZX) [ZZX]            0     0     0     0     0
# 총합                       23  1062  1058  1050  3170
#
# [153 rows x 5 columns]

# %% [markdown]
#  5. 동계와 하계 프레임을 합쳐보자. 합친 데이터프레임을 olympics_data로 이름짓는다. olympics_data 데이터프레임을 나타내보자.

# %%
olympics_data=pd.concat([summer,winter],axis=1)
olympics_data
# Out:
#                      하계참가횟수     금     은     동   하계 계  동계참가횟수     금     은  \
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)             14     0     0     2      2       0     0     0
# 알제리 (ALG)                13     5     4     8     17       3     0     0
# 아르헨티나 (ARG)              24    21    25    28     74      19     0     0
# 아르메니아 (ARM)               6     2     6     6     14       7     0     0
# 오스트랄라시아 (ANZ) [ANZ]       2     3     4     5     12       0     0     0
# ...                     ...   ...   ...   ...    ...     ...   ...   ...
# 독립 (IOA) [IOA]            3     1     0     1      2       0     0     0
# 독립 참가 (IOP) [IOP]         1     0     1     2      3       0     0     0
# 러시아 출신 올림픽 선수 (OAR)       0     0     0     0      0       1     2     6
# 혼성 (ZZX) [ZZX]            3     8     5     4     17       0     0     0
# 총합                       28  5116  5082  5490  15688      23  1062  1058
#
#                         동  동계 계
# 국가 (IOC 코드)
# ...

# %% [markdown]
# 6.하계대회 참가횟수대비 하계 총 메달 수(rate1), 동계대회 참가횟수대비 동계 총 메달 수(rate2) 열을 생성해서 olympics_data 마지막 열에 붙여보자. olympics_data 데이터프레임을 나타내보자.

# %%
rate1 = pd.DataFrame(olympics_data['하계 계'] / (olympics_data['하계참가횟수']), columns = ['하계참가횟수대비 총 메달 수'])
rate1
# Out:
#                      하계참가횟수대비 총 메달 수
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)                0.142857
# 알제리 (ALG)                   1.307692
# 아르헨티나 (ARG)                 3.083333
# 아르메니아 (ARM)                 2.333333
# 오스트랄라시아 (ANZ) [ANZ]         6.000000
# ...                              ...
# 독립 (IOA) [IOA]              0.666667
# 독립 참가 (IOP) [IOP]           3.000000
# 러시아 출신 올림픽 선수 (OAR)              NaN
# 혼성 (ZZX) [ZZX]              5.666667
# 총합                        560.285714
#
# [153 rows x 1 columns]

# %%
rate2 = pd.DataFrame(olympics_data['동계 계'] / (olympics_data['동계참가횟수']), columns = ['동계참가횟수대비 총 메달 수'])
rate2
# Out:
#                      동계참가횟수대비 총 메달 수
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)                     NaN
# 알제리 (ALG)                   0.000000
# 아르헨티나 (ARG)                 0.000000
# 아르메니아 (ARM)                 0.000000
# 오스트랄라시아 (ANZ) [ANZ]              NaN
# ...                              ...
# 독립 (IOA) [IOA]                   NaN
# 독립 참가 (IOP) [IOP]                NaN
# 러시아 출신 올림픽 선수 (OAR)        17.000000
# 혼성 (ZZX) [ZZX]                   NaN
# 총합                        137.826087
#
# [153 rows x 1 columns]

# %%
olympics_data = pd.concat([olympics_data, rate1, rate2], axis=1)
olympics_data
# Out:
#                      하계참가횟수     금     은     동   하계 계  동계참가횟수     금     은  \
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)             14     0     0     2      2       0     0     0
# 알제리 (ALG)                13     5     4     8     17       3     0     0
# 아르헨티나 (ARG)              24    21    25    28     74      19     0     0
# 아르메니아 (ARM)               6     2     6     6     14       7     0     0
# 오스트랄라시아 (ANZ) [ANZ]       2     3     4     5     12       0     0     0
# ...                     ...   ...   ...   ...    ...     ...   ...   ...
# 독립 (IOA) [IOA]            3     1     0     1      2       0     0     0
# 독립 참가 (IOP) [IOP]         1     0     1     2      3       0     0     0
# 러시아 출신 올림픽 선수 (OAR)       0     0     0     0      0       1     2     6
# 혼성 (ZZX) [ZZX]            3     8     5     4     17       0     0     0
# 총합                       28  5116  5082  5490  15688      23  1062  1058
#
#                         동  동계 계  하계참가횟수대비 총 메달 수  동계참가횟수대비 총 메달 수
# ...

# %% [markdown]
# 7.olympics_data 데이터프레임의 기본정보를 조회해보자.
# rate1 과 rate2 의 결측치(NaN) 수는 각각 몇 개인가? (코드 칸에 #을 넣고 적어보자)

# %%
olympics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 153 entries, 아프가니스탄 (AFG) to 총합
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   하계참가횟수           153 non-null    int64
#  1   금                153 non-null    int64
#  2   은                153 non-null    int64
#  3   동                153 non-null    int64
#  4   하계 계             153 non-null    int64
#  5   동계참가횟수           153 non-null    int64
#  6   금                153 non-null    int64
#  7   은                153 non-null    int64
#  8   동                153 non-null    int64
#  9   동계 계             153 non-null    int64
#  10  하계참가횟수대비 총 메달 수  152 non-null    float64
#  11  동계참가횟수대비 총 메달 수  110 non-null    float64
# dtypes: float64(2), int64(10)
# memory usage: 15.5+ KB

# %%
olympics_data.isnull().sum() #rata1의 결측치 1개 rate2의 결측치 43개로 결측치는 총 44개.
# Out:
# 하계참가횟수              0
# 금                   0
# 은                   0
# 동                   0
# 하계 계                0
# 동계참가횟수              0
# 금                   0
# 은                   0
# 동                   0
# 동계 계                0
# 하계참가횟수대비 총 메달 수     1
# 동계참가횟수대비 총 메달 수    43
# dtype: int64

# %% [markdown]
# 8.국가가 '총합'과 '연합 (EUN) [EUN]'인 행을 제거한 후 olympics_data 데이터프레임을 나타내보자.

# %%
olympics_data=olympics_data.drop(['총합','연합 (EUN) [EUN]'])
olympics_data
# Out:
#                      하계참가횟수   금   은   동  하계 계  동계참가횟수  금  은  동  동계 계  \
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)             14   0   0   2     2       0  0  0  0     0
# 알제리 (ALG)                13   5   4   8    17       3  0  0  0     0
# 아르헨티나 (ARG)              24  21  25  28    74      19  0  0  0     0
# 아르메니아 (ARM)               6   2   6   6    14       7  0  0  0     0
# 오스트랄라시아 (ANZ) [ANZ]       2   3   4   5    12       0  0  0  0     0
# ...                     ...  ..  ..  ..   ...     ... .. .. ..   ...
# 짐바브웨 (ZIM) [ZIM]         13   3   4   1     8       1  0  0  0     0
# 독립 (IOA) [IOA]            3   1   0   1     2       0  0  0  0     0
# 독립 참가 (IOP) [IOP]         1   0   1   2     3       0  0  0  0     0
# 러시아 출신 올림픽 선수 (OAR)       0   0   0   0     0       1  2  6  9    17
# 혼성 (ZZX) [ZZX]            3   8   5   4    17       0  0  0  0     0
#
#                      하계참가횟수대비 총 메달 수  동계참가횟수대비 총 메달 수
# 국가 (IOC 코드)
# 아프가니스탄 (AFG)                0.142857              NaN
# ...

# %% [markdown]
# 9.하계참가횟수 당 평균 메달 수가 15이상인 국가를 나타내보자. 이 중 아시아 국가는 어느 국가인가?

# %%
olympics_data[olympics_data['하계참가횟수대비 총 메달 수']>=15] #이 중 아시아 국가는 중화인민공화국(중국),일본,대한민국이다.
# Out:
#                               하계참가횟수     금    은    동  하계 계  동계참가횟수    금    은  \
# 국가 (IOC 코드)
# 오스트레일리아 (AUS) [AUS] [Z]           26   147  163  187   497      19    5    5
# 중화인민공화국 (CHN) [CHN]               10   224  167  155   546      11   13   28
# 프랑스 (FRA) [O] [P] [Z]             28   212  241  263   716      23   36   35
# 독일 (GER) [GER] [Z]                16   191  194  230   615      12   92   88
# 독일 연합 (EUA) [EUA]                  3    28   54   36   118       3    8    6
# 동독 (GDR) [GDR]                     5   153  129  127   409       6   39   36
# 서독 (FRG) [FRG]                     5    56   67   81   204       6   11   15
# 영국 (GBR) [GBR] [Z]                28   263  295  293   851      23   11    4
# 헝가리 (HUN)                         26   175  147  169   491      23    1    2
# 이탈리아 (ITA) [M] [S]                27   206  178  193   577      23   40   36
# 일본 (JPN)                          22   142  136  161   439      21   14   22
# ...

# %% [markdown]
# 10. olympics_data 데이터프레임의 rate1 변수가 높은대로 정렬해보자. 어느 국가가 가장 하계대회 참가횟수당 평균 메달 수가 많은가? (코드 칸에 #을 넣고 나라 이름과 참가횟수 당 평균 메달 수까지 적어보자.)

# %%
olympics_data.sort_values('하계참가횟수대비 총 메달 수',ascending=False) #소련, 하계참가횟수 당 평균 메달 수:112.22개
# Out:
#                               하계참가횟수     금    은    동  하계 계  동계참가횟수    금    은  \
# 국가 (IOC 코드)
# 소련 (URS) [URS]                     9   395  319  296  1010       9   78   57
# 미국 (USA) [P] [Q] [R] [Z] [F]      27  1022  795  706  2523      23  105  112
# 동독 (GDR) [GDR]                     5   153  129  127   409       6   39   36
# 러시아 (RUS) [RUS]                    6   148  125  153   426       6   47   38
# 중화인민공화국 (CHN) [CHN]               10   224  167  155   546      11   13   28
# ...                              ...   ...  ...  ...   ...     ...  ...  ...
# 과테말라 (GUA)                        14     0    1    0     1       1    0    0
# 가이아나 (GUY) [GUY]                  17     0    0    1     1       0    0    0
# 버뮤다 (BER)                         18     0    0    1     1       8    0    0
# 리히텐슈타인 (LIE)                      17     0    0    0     0      19    2    2
# 러시아 출신 올림픽 선수 (OAR)                0     0    0    0     0       1    2    6
#
# ...

# %% [markdown]
# 11.rate1 변수가 높은 순서대로 정렬하여 엑셀파일로 추출해보자. 파일 이름은 olympics.xlsx로 한다.

# %%
olympics_data=olympics_data.sort_values('하계참가횟수대비 총 메달 수',ascending=False)
olympics_data.to_excel('olympics.xlsx')

# %% [markdown]
# 12.rate2 변수가 높은대로 정렬해보자. 어느 국가가 가장 동계대회 참가횟수당 평균 메달 수가 많은가? (코드 칸에 #을 넣고 나라 이름과 참가횟수 당 평균 메달 수까지 적어보자.)

# %%
olympics_data.sort_values('동계참가횟수대비 총 메달 수',ascending=False) #소련, 동계참가횟수 당 평균 메달 수:21.55개
# Out:
#                      하계참가횟수    금    은    동  하계 계  동계참가횟수   금   은   동  동계 계  \
# 국가 (IOC 코드)
# 소련 (URS) [URS]            9  395  319  296  1010       9  78  57  59   194
# 독일 (GER) [GER] [Z]       16  191  194  230   615      12  92  88  60   240
# 러시아 (RUS) [RUS]           6  148  125  153   426       6  47  38  35   120
# 동독 (GDR) [GDR]            5  153  129  127   409       6  39  36  35   110
# 러시아 출신 올림픽 선수 (OAR)       0    0    0    0     0       1   2   6   9    17
# ...                     ...  ...  ...  ...   ...     ...  ..  ..  ..   ...
# 가봉 (GAB)                 10    0    1    0     1       0   0   0   0     0
# 바베이도스 (BAR) [BAR]        12    0    0    1     1       0   0   0   0     0
# 수단 (SUD)                 12    0    1    0     1       0   0   0   0     0
# 이라크 (IRQ)                14    0    0    1     1       0   0   0   0     0
# 가이아나 (GUY) [GUY]         17    0    0    1     1       0   0   0   0     0
#
#                      하계참가횟수대비 총 메달 수  동계참가횟수대비 총 메달 수
# ...

# %% [markdown]
# 13. 하계참가횟수, 동계참가횟수, rate1, rate2의 상관관계를 히트맵(matplotlib & seaborn)으로 그려보자.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data=olympics_data[['하계참가횟수','동계참가횟수','하계참가횟수대비 총 메달 수','동계참가횟수대비 총 메달 수']].corr(), square=True, annot=True, cmap='Blues')
plt.show()
